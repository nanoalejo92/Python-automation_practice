# %%
import pandas as pd
from sqlalchemy import create_engine
from tabulate import tabulate
from credentials import username, password

# connection details
server = "jarbdatabase.database.windows.net"
database = "Azure_EmployeeDB"
username = username
password = password
driver = "ODBC Driver 18 for SQL Server"


# IMPORTANT: use the proper ODBC driver installed on your machine
#driver = "ODBC Driver 18 for SQL Server"

# create SQLAlchemy engine string with Active Directory Interactive auth
conn_str = (
    f"DRIVER={{{driver}}};" 
    f"SERVER={server};"
    f"DATABASE={database};"
    # 💡 CHANGE AUTHENTICATION METHOD 💡
    "Authentication=ActiveDirectoryPassword;" 
    f"UID={username};"  # Pass the username from credentials.py
    f"PWD={password};"  # Pass the password from credentials.py
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    # LoginTimeout can be shorter now, e.g., 30 or 60
    "LoginTimeout=60;"
)

# create engine
engine = create_engine(
    f"mssql+pyodbc://{username}:{password}@{server}:1433/{database}?driver={driver}", 
    connect_args={
        "cnxn_str": conn_str, 
        "unicode_results": True,
    }
)

print(f"Connection parameters are set for {database}. Attempting non-interactive login...")

# ... (rest of your try/except block)

# now this is fully supported by pandas
query = "SELECT TOP 10 * FROM [SalesLT].[Customer]"
df = pd.read_sql(query, engine)
print(tabulate(df, headers = 'keys', tablefmt = 'psql'))
# Out:
# Connection parameters are set for Azure_EmployeeDB. Attempting non-interactive login...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
#    (...)    445
#     446 """
# --> 447 return _ConnectionFairy._checkout(self)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:388, in Pool._create_connection(self)
#     386 """Called by subclasses to create a new ConnectionRecord."""
# --> 388 return _ConnectionRecord(self)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:899, in _ConnectionRecord.__connect(self)
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:895, in _ConnectionRecord.__connect(self)
#     894 self.starttime = time.time()
# --> 895 self.dbapi_connection = connection = pool._invoke_creator(self)
#     896 pool.logger.debug("Created new connection %r", connection)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/create.py:661, in create_engine.<locals>.connect(connection_record)
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 47
#      43 # ... (rest of your try/except block)
#      44
#      45 # now this is fully supported by pandas
#      46 query = "SELECT TOP 10 * FROM [SalesLT].[Customer]"
# ---> 47 df = pd.read_sql(query, engine)
#      48 print(tabulate(df, headers = 'keys', tablefmt = 'psql'))
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     703     dtype_backend = "numpy"  # type: ignore[assignment]
#     704 assert dtype_backend is not lib.no_default
# --> 706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
#     708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#    (...)    716             dtype=dtype,
#     717         )
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/pandas/io/sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     905     raise ImportError("Using URI string without sqlalchemy installed.")
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/pandas/io/sql.py:1648, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1646     self.exit_stack.callback(con.dispose)
#    1647 if isinstance(con, Engine):
# -> 1648     con = self.exit_stack.enter_context(con.connect())
#    1649 if need_transaction and not con.in_transaction():
#    1650     self.exit_stack.enter_context(con.begin())
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3277, in Engine.connect(self)
#    3254 def connect(self) -> Connection:
#    3255     """Return a new :class:`_engine.Connection` object.
#    3256
#    3257     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3274
#    3275     """
# -> 3277     return self._connection_cls(self)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3279 def raw_connection(self) -> PoolProxiedConnection:
#    3280     """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282     The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300     """
# -> 3301     return self.pool.connect()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)    445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File ~/Python-automation_practice/azureenv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (pyodbc.OperationalError) ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['ODBC Driver 18 for SQL Server']
