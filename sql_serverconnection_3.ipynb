# %%
import pyodbc as odbc

cnxn_str = (
    'DRIVER={ODBC Driver 18 for SQL Server};'
    'SERVER=jarbdatabase.database.windows.net,1433;'
    'DATABASE=Azure_EmployeeDB;'
    'UID=johan.robelto.bayona@johanrobeltobayonaoutlook.onmicrosoft.com;'
    'PWD=Outnano92;'
    'Authentication=ActiveDirectoryPassword;'
    'Encrypt=yes;'
    'TrustServerCertificate=no'
)

conn = odbc.connect(cnxn_str, timeout=10)
cursor = conn.cursor()
cursor.execute("SELECT TOP 10 * FROM [SalesLT].[Customer]")
rows = cursor.fetchall()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[9], line 14
#       1 import pyodbc as odbc
#       3 cnxn_str = (
#       4     'DRIVER={ODBC Driver 18 for SQL Server};'
#       5     'SERVER=jarbdatabase.database.windows.net,1433;'
#    (...)
#      11     'TrustServerCertificate=no'
#      12 )
# ---> 14 conn = odbc.connect(cnxn_str, timeout=10)
#      15 cursor = conn.cursor()
#      16 cursor.execute("SELECT TOP 10 * FROM [SalesLT].[Customer]")
#
# ...
